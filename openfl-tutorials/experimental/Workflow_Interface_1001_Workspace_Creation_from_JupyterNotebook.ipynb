# %% [markdown]
# # Workflow Interface 1001: Workspace Creation from Jupyter Notebook

# %% [markdown]
# This tutorial demonstrates the methodology to convert a Federated Learning experiment developed in Jupyter Notebook into a Workspace that can be deployed using Aggregator Based Workflow
#
# OpenFL experimental Workflow Interface enables the user to simulate a Federated Learning experiment using **LocalRuntime**. Once the simulation is ready, the methodology described in this tutorial enables the user to convert this experiment into an OpenFL workspace that can be deployed using the Aggregator-Based-Workflow
#
# ##### High Level Overview of Methodology
# 1. User annotates the relevant cells of the Jupyter notebook with `#| export` directive
# 2. We then Leverage `nbdev` functionality to export these annotated cells of Jupyter notebook into a Python script
# 3. Utilize OpenFL experimental module `WorkspaceExport` to convert the Python script into a OpenFL workspace
# 4. User can utilize the experimental `fx` commands to deploy and run the federation seamlessly
#
#
# The methodology is described using an existing [OpenFL Watermarking Tutorial](https://github.com/securefederatedai/openfl/blob/develop/openfl-tutorials/experimental/Workflow_Interface_301_MNIST_Watermarking.ipynb). Let's get started !

# %% [markdown]
# # Getting Started

# %% [markdown]
# Initially, we start by specifying the module where cells marked with the `#| export` directive will be automatically exported.
#
# In the following cell, `#| default_exp experiment `indicates that the exported file will be named 'experiment'. This name can be modified based on user's requirement & preferences

# %%
#| default_exp experiment

# %% [markdown]
# Once we have specified the name of the module, subsequent cells of the notebook need to be *appended* by the `#| export` directive as shown below. User should ensure that *all* the notebook functionality required in the Federated Learning experiment is included in this directive

# %% [markdown]
# We start by installing OpenFL and dependencies of the workflow interface
# > These dependencies are required to be exported and become the requirements for the Federated Learning Workspace

# %%
#| export

# !pip install git+https://github.com/intel/openfl.git
# !pip install -r requirements_workflow_interface.txt

# !pip install matplotlib
# !pip install torch
# !pip install torchvision
# !pip install git+https://github.com/pyviz-topics/imagen.git@master
# !pip install imagen

# Uncomment this if running in Google Colab
#!pip install -r https://raw.githubusercontent.com/intel/openfl/develop/openfl-tutorials/experimental/requirements_workflow_interface.txt
#import os
#os.environ["USERNAME"] = "colab"
# Out:
# Collecting git+https://github.com/intel/openfl.git
#   Cloning https://github.com/intel/openfl.git to /tmp/pip-req-build-yg_5g7sj
#   Running command git clone --filter=blob:none --quiet https://github.com/intel/openfl.git /tmp/pip-req-build-yg_5g7sj
#   Resolved https://github.com/intel/openfl.git to commit d4108fb49b2d932d3647b12a370e42a0231cbc40
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click==8.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (8.0.1)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (6.0.1)
# Requirement already satisfied: cloudpickle in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (3.0.0)
# Requirement already satisfied: cryptography>=3.4.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (41.0.5)
# Requirement already satisfied: docker in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (6.1.3)
# Requirement already satisfied: dynaconf==3.1.7 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (3.1.7)
# Requirement already satisfied: flatten_json in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (0.1.14)
# Requirement already satisfied: grpcio>=1.56.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (1.59.2)
# Requirement already satisfied: ipykernel in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (6.26.0)
# Requirement already satisfied: jupyterlab in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (4.0.8)
# Requirement already satisfied: numpy in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (1.24.4)
# Requirement already satisfied: pandas in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (2.0.3)
# Requirement already satisfied: protobuf>=3.20.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (3.20.3)
# Requirement already satisfied: pyzmq<=24.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (24.0.1)
# Requirement already satisfied: requests in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (2.31.0)
# Requirement already satisfied: rich in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (13.6.0)
# Requirement already satisfied: scikit-learn in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (1.3.2)
# Requirement already satisfied: tensorboard in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (2.14.0)
# Requirement already satisfied: tensorboardX<=2.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (2.6)
# Requirement already satisfied: tqdm in /home/mansisha/v_sec/lib/python3.8/site-packages (from openfl==1.5) (4.66.1)
# Requirement already satisfied: cffi>=1.12 in /home/mansisha/v_sec/lib/python3.8/site-packages (from cryptography>=3.4.6->openfl==1.5) (1.16.0)
# Requirement already satisfied: packaging in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboardX<=2.6->openfl==1.5) (23.2)
# Requirement already satisfied: urllib3>=1.26.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from docker->openfl==1.5) (1.26.18)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from docker->openfl==1.5) (1.6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->openfl==1.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->openfl==1.5) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->openfl==1.5) (2023.7.22)
# Requirement already satisfied: six in /home/mansisha/v_sec/lib/python3.8/site-packages (from flatten_json->openfl==1.5) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (1.5.8)
# Requirement already satisfied: psutil in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (5.9.4)
# Requirement already satisfied: tornado>=6.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipykernel->openfl==1.5) (5.13.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (2.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (6.8.0)
# Requirement already satisfied: importlib-resources>=1.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (6.1.1)
# Requirement already satisfied: jinja2>=3.0.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (3.1.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (2.25.1)
# Requirement already satisfied: notebook-shim>=0.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (0.2.3)
# Requirement already satisfied: tomli in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab->openfl==1.5) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pandas->openfl==1.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pandas->openfl==1.5) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pandas->openfl==1.5) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from rich->openfl==1.5) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from rich->openfl==1.5) (2.16.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from rich->openfl==1.5) (4.8.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from scikit-learn->openfl==1.5) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from scikit-learn->openfl==1.5) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from scikit-learn->openfl==1.5) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (2.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (3.5.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (44.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (3.0.1)
# Requirement already satisfied: wheel>=0.26 in /home/mansisha/v_sec/lib/python3.8/site-packages (from tensorboard->openfl==1.5) (0.41.3)
# Requirement already satisfied: pycparser in /home/mansisha/v_sec/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=3.4.6->openfl==1.5) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->openfl==1.5) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyterlab->openfl==1.5) (3.17.0)
# Requirement already satisfied: backcall in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (0.2.0)
# Requirement already satisfied: decorator in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (0.19.1)
# Requirement already satisfied: pickleshare in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (3.0.39)
# Requirement already satisfied: stack-data in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->openfl==1.5) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jinja2>=3.0.3->jupyterlab->openfl==1.5) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->openfl==1.5) (3.11.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (4.0.0)
# Requirement already satisfied: argon2-cffi in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (7.11.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (5.9.2)
# Requirement already satisfied: overrides in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.18.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.17.1)
# Requirement already satisfied: babel>=2.10 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (4.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich->openfl==1.5) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->openfl==1.5) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (0.12.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (6.1.0)
# Requirement already satisfied: defusedxml in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (1.2.1)
# Requirement already satisfied: fastjsonschema in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (2.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->openfl==1.5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mansisha/v_sec/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->openfl==1.5) (0.2.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->openfl==1.5) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->openfl==1.5) (3.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/mansisha/v_sec/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->openfl==1.5) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->openfl==1.5) (2.4.1)
# Requirement already satisfied: pure-eval in /home/mansisha/v_sec/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->openfl==1.5) (0.2.2)
# Requirement already satisfied: webencodings in /home/mansisha/v_sec/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (0.5.1)
# Requirement already satisfied: fqdn in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (1.5.1)
# Requirement already satisfied: isoduration in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (2.4)
# Requirement already satisfied: uri-template in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (1.13)
# Requirement already satisfied: soupsieve>1.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->openfl==1.5) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/mansisha/v_sec/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->openfl==1.5) (2.8.19.14)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: dill==0.3.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 1)) (0.3.6)
# Requirement already satisfied: chardet in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 2)) (5.2.0)
# Requirement already satisfied: charset-normalizer in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 3)) (3.3.2)
# Requirement already satisfied: metaflow==2.7.15 in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 4)) (2.7.15)
# Requirement already satisfied: ray==2.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 5)) (2.2.0)
# Requirement already satisfied: nbdev==2.3.12 in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 6)) (2.3.12)
# Requirement already satisfied: astor==0.8.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from -r requirements_workflow_interface.txt (line 7)) (0.8.1)
# Requirement already satisfied: requests in /home/mansisha/v_sec/lib/python3.8/site-packages (from metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (2.31.0)
# Requirement already satisfied: boto3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (1.28.83)
# Requirement already satisfied: pylint in /home/mansisha/v_sec/lib/python3.8/site-packages (from metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (3.0.2)
# Requirement already satisfied: attrs in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (23.1.0)
# Requirement already satisfied: click>=7.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (8.0.1)
# Requirement already satisfied: filelock in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (3.13.1)
# Requirement already satisfied: jsonschema in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (1.0.7)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (3.20.3)
# Requirement already satisfied: pyyaml in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (6.0.1)
# Requirement already satisfied: aiosignal in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (1.3.1)
# Requirement already satisfied: frozenlist in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (1.4.0)
# Requirement already satisfied: virtualenv>=20.0.24 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (20.24.6)
# Requirement already satisfied: grpcio>=1.32.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (1.59.2)
# Requirement already satisfied: numpy>=1.16 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (1.24.4)
# Requirement already satisfied: fastcore>=1.5.27 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (1.5.29)
# Requirement already satisfied: execnb>=0.1.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.1.5)
# Requirement already satisfied: astunparse in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (1.6.3)
# Requirement already satisfied: ghapi>=1.0.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (1.0.4)
# Requirement already satisfied: watchdog in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (3.0.0)
# Requirement already satisfied: asttokens in /home/mansisha/v_sec/lib/python3.8/site-packages (from nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (2.4.1)
# Requirement already satisfied: ipython in /home/mansisha/v_sec/lib/python3.8/site-packages (from execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (8.12.3)
# Requirement already satisfied: pip in /home/mansisha/v_sec/lib/python3.8/site-packages (from fastcore>=1.5.27->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (23.2.1)
# Requirement already satisfied: packaging in /home/mansisha/v_sec/lib/python3.8/site-packages (from fastcore>=1.5.27->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (23.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/mansisha/v_sec/lib/python3.8/site-packages (from virtualenv>=20.0.24->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (0.3.7)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from virtualenv>=20.0.24->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (3.11.0)
# Requirement already satisfied: six>=1.12.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from asttokens->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from astunparse->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.41.3)
# Requirement already satisfied: botocore<1.32.0,>=1.31.83 in /home/mansisha/v_sec/lib/python3.8/site-packages (from boto3->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (1.31.83)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from boto3->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from boto3->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (0.7.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (6.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jsonschema->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (0.12.0)
# Requirement already satisfied: astroid<=3.1.0-dev0,>=3.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pylint->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (3.0.1)
# Requirement already satisfied: isort<6,>=4.2.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pylint->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (5.12.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pylint->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pylint->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (0.12.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pylint->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (4.8.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pylint->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (2023.7.22)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from botocore<1.32.0,>=1.31.83->boto3->metaflow==2.7.15->-r requirements_workflow_interface.txt (line 4)) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema->ray==2.2.0->-r requirements_workflow_interface.txt (line 5)) (3.17.0)
# Requirement already satisfied: backcall in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.2.0)
# Requirement already satisfied: decorator in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.1.6)
# Requirement already satisfied: pickleshare in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (2.16.1)
# Requirement already satisfied: stack-data in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (5.13.0)
# Requirement already satisfied: pexpect>4.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mansisha/v_sec/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.2.9)
# Requirement already satisfied: executing>=1.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (2.0.1)
# Requirement already satisfied: pure-eval in /home/mansisha/v_sec/lib/python3.8/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev==2.3.12->-r requirements_workflow_interface.txt (line 6)) (0.2.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /home/mansisha/v_sec/lib/python3.8/site-packages (3.7.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch in /home/mansisha/v_sec/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: filelock in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.52)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/mansisha/v_sec/lib/python3.8/site-packages (from sympy->torch) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchvision in /home/mansisha/v_sec/lib/python3.8/site-packages (0.16.0)
# Requirement already satisfied: numpy in /home/mansisha/v_sec/lib/python3.8/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: requests in /home/mansisha/v_sec/lib/python3.8/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torchvision) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: filelock in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (4.8.0)
# Requirement already satisfied: sympy in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (1.12)
# Requirement already satisfied: networkx in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from torch==2.1.0->torchvision) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mansisha/v_sec/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0->torchvision) (12.3.52)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from jinja2->torch==2.1.0->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/mansisha/v_sec/lib/python3.8/site-packages (from sympy->torch==2.1.0->torchvision) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/pyviz-topics/imagen.git@master
#   Cloning https://github.com/pyviz-topics/imagen.git (to revision master) to /tmp/pip-req-build-gg41g7si
#   Running command git clone --filter=blob:none --quiet https://github.com/pyviz-topics/imagen.git /tmp/pip-req-build-gg41g7si
#   Resolved https://github.com/pyviz-topics/imagen.git to commit 649e24236aabf0432928a88cbecddf74e1610142
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: holoviews>=1.0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from imagen==2.1.0) (1.17.1)
# Requirement already satisfied: numpy>=1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from imagen==2.1.0) (1.24.4)
# Requirement already satisfied: param>=1.3.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from imagen==2.1.0) (2.0.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from holoviews>=1.0.1->imagen==2.1.0) (3.0.0)
# Requirement already satisfied: panel>=0.13.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from holoviews>=1.0.1->imagen==2.1.0) (1.2.3)
# Requirement already satisfied: colorcet in /home/mansisha/v_sec/lib/python3.8/site-packages (from holoviews>=1.0.1->imagen==2.1.0) (3.0.1)
# Requirement already satisfied: packaging in /home/mansisha/v_sec/lib/python3.8/site-packages (from holoviews>=1.0.1->imagen==2.1.0) (23.2)
# Requirement already satisfied: pandas>=0.20.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from holoviews>=1.0.1->imagen==2.1.0) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pandas>=0.20.0->holoviews>=1.0.1->imagen==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pandas>=0.20.0->holoviews>=1.0.1->imagen==2.1.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from pandas>=0.20.0->holoviews>=1.0.1->imagen==2.1.0) (2023.3)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.1.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (2023.10.1)
# Requirement already satisfied: markdown in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.5.1)
# Requirement already satisfied: markdown-it-py in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.0.0)
# Requirement already satisfied: linkify-it-py in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (0.4.0)
# Requirement already satisfied: requests in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (4.66.1)
# Requirement already satisfied: bleach in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (6.1.0)
# Requirement already satisfied: typing-extensions in /home/mansisha/v_sec/lib/python3.8/site-packages (from panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (4.8.0)
# Requirement already satisfied: pyct>=0.4.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from colorcet->holoviews>=1.0.1->imagen==2.1.0) (0.5.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/mansisha/v_sec/lib/python3.8/site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (1.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (10.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/mansisha/v_sec/lib/python3.8/site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (6.3.3)
# Requirement already satisfied: six>=1.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->holoviews>=1.0.1->imagen==2.1.0) (1.16.0)
# Requirement already satisfied: webencodings in /home/mansisha/v_sec/lib/python3.8/site-packages (from bleach->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (0.5.1)
# Requirement already satisfied: uc-micro-py in /home/mansisha/v_sec/lib/python3.8/site-packages (from linkify-it-py->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (1.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/mansisha/v_sec/lib/python3.8/site-packages (from markdown->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (6.8.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from markdown-it-py->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mansisha/v_sec/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (2023.7.22)
# Requirement already satisfied: zipp>=0.5 in /home/mansisha/v_sec/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mansisha/v_sec/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews>=1.0.1->imagen==2.1.0) (2.1.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We now define our dataloaders, model, optimizer, and some helper functions like we would for any other deep learning experiment
#
# > This cell and all the subsequent cells are important ingredients of the Federated Learning experiment and therefore annotated with the `#| export` directive

# %%
# | export

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import torchvision
import numpy as np
import random
import pathlib
import os
import matplotlib
import matplotlib.pyplot as plt
import PIL.Image as Image
import imagen as ig
import numbergen as ng
import os

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# MNIST Train and Test datasets
mnist_train = torchvision.datasets.MNIST(
    "./files/",
    train=True,
    download=True,
    transform=torchvision.transforms.Compose(
        [
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize((0.1307,), (0.3081,)),
        ]
    ),
)

mnist_test = torchvision.datasets.MNIST(
    "./files/",
    train=False,
    download=True,
    transform=torchvision.transforms.Compose(
        [
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize((0.1307,), (0.3081,)),
        ]
    ),
)


class Net(nn.Module):
    def __init__(self, dropout=0.0):
        super(Net, self).__init__()
        self.dropout = dropout
        self.block = nn.Sequential(
            nn.Conv2d(1, 32, 2),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(32, 64, 2),
            nn.MaxPool2d(2),
            nn.ReLU(),
            nn.Conv2d(64, 128, 2),
            nn.ReLU(),
        )
        self.fc1 = nn.Linear(128 * 5**2, 200)
        self.fc2 = nn.Linear(200, 10)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        x = self.dropout(x)
        out = self.block(x)
        out = out.view(-1, 128 * 5**2)
        out = self.dropout(out)
        out = self.relu(self.fc1(out))
        out = self.dropout(out)
        out = self.fc2(out)
        return F.log_softmax(out, 1)


def inference(network, test_loader):
    network.eval()
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = network(data)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    accuracy = float(correct / len(test_loader.dataset))
    return accuracy


def train_model(model, optimizer, data_loader, entity, round_number, log=False):
    # Helper function to train the model
    train_loss = 0
    log_interval = 20
    model.train()
    for batch_idx, (X, y) in enumerate(data_loader):
        optimizer.zero_grad()

        output = model(X)
        loss = F.nll_loss(output, y)
        loss.backward()

        optimizer.step()

        train_loss += loss.item() * len(X)
        if batch_idx % log_interval == 0 and log:
            print("{:<20} Train Epoch: {:<3} [{:<3}/{:<4} ({:<.0f}%)] Loss: {:<.6f}".format(
                    entity,
                    round_number,
                    batch_idx * len(X),
                    len(data_loader.dataset),
                    100.0 * batch_idx / len(data_loader),
                    loss.item(),
                )
            )
    train_loss /= len(data_loader.dataset)
    return train_loss
# Out:
# /home/mansisha/v_sec/lib/python3.8/site-packages/imagen/patterngenerator.py:68: HoloviewsDeprecationWarning: 'BoundingRegionParameter' is deprecated and will be removed in version 1.18.
#   bounds  = BoundingRegionParameter(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 15
#      13 import matplotlib.pyplot as plt
#      14 import PIL.Image as Image
# ---> 15 import imagen as ig
#      16 import numbergen as ng
#      17 import os
#
# File ~/v_sec/lib/python3.8/site-packages/imagen/__init__.py:32
#      29 from param import ClassSelector
#      31 # Imported here so that all PatternGenerators will be in the same package
# ---> 32 from .patterngenerator import PatternGenerator, CompositeBase, Composite
#      33 from .patterngenerator import Constant, ChannelTransform, ChannelGenerator # pyflakes:ignore (API import)
#      34 from .patterngenerator import CorrelateChannels, ComposeChannels # pyflakes:ignore (API import)
#
# File ~/v_sec/lib/python3.8/site-packages/imagen/patterngenerator.py:416
#     411         return fromarray(arr, mode)
#     414 # Override class type; must be set here rather than when mask_shape is declared,
#     415 # to avoid referring to class not yet constructed
# --> 416 PatternGenerator.params('mask_shape').class_=PatternGenerator
#     420 # Trivial example of a PatternGenerator, provided for when a default is
#     421 # needed.  The other concrete PatternGenerator classes are stored
#     422 # elsewhere, to be imported as needed.
#     424 class Constant(PatternGenerator):
#
# AttributeError: type object 'PatternGenerator' has no attribute 'params'

# %% [markdown]
# Next we define the dataset required for watermarking

# %%
#| export

watermark_dir = "./files/watermark-dataset/MWAFFLE/"


def generate_watermark(
    x_size=28, y_size=28, num_class=10, num_samples_per_class=10, img_dir=watermark_dir
):
    """
    Generate Watermark by superimposing a pattern on noisy background.

    Parameters
    ----------
    x_size: x dimension of the image
    y_size: y dimension of the image
    num_class: number of classes in the original dataset
    num_samples_per_class: number of samples to be generated per class
    img_dir: directory for saving watermark dataset

    Reference
    ---------
    WAFFLE: Watermarking in Federated Learning (https://arxiv.org/abs/2008.07298)

    """
    x_pattern = int(x_size * 2 / 3.0 - 1)
    y_pattern = int(y_size * 2 / 3.0 - 1)

    np.random.seed(0)
    for cls in range(num_class):
        patterns = []
        random_seed = 10 + cls
        patterns.append(
            ig.Line(
                xdensity=x_pattern,
                ydensity=y_pattern,
                thickness=0.001,
                orientation=np.pi * ng.UniformRandom(seed=random_seed),
                x=ng.UniformRandom(seed=random_seed) - 0.5,
                y=ng.UniformRandom(seed=random_seed) - 0.5,
                scale=0.8,
            )
        )
        patterns.append(
            ig.Arc(
                xdensity=x_pattern,
                ydensity=y_pattern,
                thickness=0.001,
                orientation=np.pi * ng.UniformRandom(seed=random_seed),
                x=ng.UniformRandom(seed=random_seed) - 0.5,
                y=ng.UniformRandom(seed=random_seed) - 0.5,
                size=0.33,
            )
        )

        pat = np.zeros((x_pattern, y_pattern))
        for i in range(6):
            j = np.random.randint(len(patterns))
            pat += patterns[j]()
        res = pat > 0.5
        pat = res.astype(int)

        x_offset = np.random.randint(x_size - x_pattern + 1)
        y_offset = np.random.randint(y_size - y_pattern + 1)

        for i in range(num_samples_per_class):
            base = np.random.rand(x_size, y_size)
            # base = np.zeros((x_input, y_input))
            base[
                x_offset : x_offset + pat.shape[0],
                y_offset : y_offset + pat.shape[1],
            ] += pat
            d = np.ones((x_size, x_size))
            img = np.minimum(base, d)
            if not os.path.exists(img_dir + str(cls) + "/"):
                os.makedirs(img_dir + str(cls) + "/")
            plt.imsave(
                img_dir + str(cls) + "/wm_" + str(i + 1) + ".png",
                img,
                cmap=matplotlib.cm.gray,
            )


# If the Watermark dataset does not exist, generate and save the Watermark images
watermark_path = pathlib.Path(watermark_dir)
if watermark_path.exists() and watermark_path.is_dir():
    print(
        f"Watermark dataset already exists at: {watermark_path}. Proceeding to next step ... "
    )
    pass
else:
    print(f"Generating Watermark dataset... ")
    generate_watermark()


class WatermarkDataset(torch.utils.data.Dataset):
    def __init__(self, images_dir, label_dir=None, transforms=None):
        self.images_dir = os.path.abspath(images_dir)
        self.image_paths = [
            os.path.join(self.images_dir, d) for d in os.listdir(self.images_dir)
        ]
        self.label_paths = label_dir
        self.transform = transforms
        temp = []

        # Recursively counting total number of images in the directory
        for image_path in self.image_paths:
            for path in os.walk(image_path):
                if len(path) <= 1:
                    continue
                path = path[2]
                for im_n in [image_path + "/" + p for p in path]:
                    temp.append(im_n)
        self.image_paths = temp

        if len(self.image_paths) == 0:
            raise Exception(f"No file(s) found under {images_dir}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_filepath = self.image_paths[idx]
        image = Image.open(image_filepath)
        image = image.convert("RGB")
        image = self.transform(image)
        label = int(image_filepath.split("/")[-2])

        return image, label


def get_watermark_transforms():
    return torchvision.transforms.Compose(
        [
            torchvision.transforms.Grayscale(),
            torchvision.transforms.Resize(28),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,)),  # Normalize
        ]
    )


watermark_data = WatermarkDataset(
    images_dir=watermark_dir,
    transforms=get_watermark_transforms(),
)

# Set display_watermark to True to display the Watermark dataset
display_watermark = False
if display_watermark:
    # Inspect and plot the Watermark Images
    wm_images = np.empty((100, 28, 28))
    wm_labels = np.empty([100, 1], dtype=int)

    for i in range(len(watermark_data)):
        img, label = watermark_data[i]
        wm_labels[label * 10 + i % 10] = label
        wm_images[label * 10 + i % 10, :, :] = img.numpy()

    fig = plt.figure(figsize=(120, 120))
    for i in range(100):
        plt.subplot(10, 10, i + 1)
        plt.imshow(wm_images[i], interpolation="none")
        plt.title("Label: {}".format(wm_labels[i]), fontsize=80)

# %% [markdown]
# Next we import the `FLSpec`, `LocalRuntime`, placement decorators (`aggregator/collaborator`)

# %%
#| export

from copy import deepcopy

from openfl.experimental.interface import FLSpec, Aggregator, Collaborator
from openfl.experimental.runtime import LocalRuntime
from openfl.experimental.placement import aggregator, collaborator

def FedAvg(agg_model, models, weights=None):
    state_dicts = [model.state_dict() for model in models]
    state_dict = agg_model.state_dict()
    for key in models[0].state_dict():
        state_dict[key] = torch.from_numpy(np.average([state[key].numpy() for state in state_dicts],
                                                      axis=0, 
                                                      weights=weights))
        
    agg_model.load_state_dict(state_dict)
    return agg_model

# %% [markdown]
# Let us now define the Workflow for Watermark embedding.

# %%
#| export

class FederatedFlow_MNIST_Watermarking(FLSpec):
    """
    This Flow demonstrates Watermarking on a Deep Learning Model in Federated Learning
    Ref: WAFFLE: Watermarking in Federated Learning (https://arxiv.org/abs/2008.07298)
    """

    def __init__(
        self,
        model=None,
        optimizer=None,
        watermark_pretrain_optimizer=None,
        watermark_retrain_optimizer=None,
        round_number=0,
        **kwargs,
    ):
        super().__init__(**kwargs)

        if model is not None:
            self.model = model
            self.optimizer = optimizer
            self.watermark_pretrain_optimizer = watermark_pretrain_optimizer
            self.watermark_retrain_optimizer = watermark_retrain_optimizer
        else:
            self.model = Net()
            self.optimizer = optim.SGD(
                self.model.parameters(), lr=learning_rate, momentum=momentum
            )
            self.watermark_pretrain_optimizer = optim.SGD(
                self.model.parameters(),
                lr=watermark_pretrain_learning_rate,
                momentum=watermark_pretrain_momentum,
                weight_decay=watermark_pretrain_weight_decay,
            )
            self.watermark_retrain_optimizer = optim.SGD(
                self.model.parameters(), lr=watermark_retrain_learning_rate
            )
        self.round_number = round_number
        self.watermark_pretraining_completed = False

    @aggregator
    def start(self):
        """
        This is the start of the Flow.
        """

        print(f"<Agg>: Start of flow ... ")
        self.collaborators = self.runtime.collaborators

        # Randomly select a fraction of actual collaborator every round
        fraction = 0.5
        if int(fraction * len(self.collaborators)) < 1:
            raise Exception(
                f"Cannot run training with {fraction*100}% selected collaborators out of {len(self.collaborators)} Collaborators. Atleast one collaborator is required to run the training"
            )
        self.subset_collaborators = random.sample(
            self.collaborators, int(fraction * (len(self.collaborators)))
        )

        self.next(self.watermark_pretrain)

    @aggregator
    def watermark_pretrain(self):
        """
        Pre-Train the Model before starting Federated Learning.
        """
        if not self.watermark_pretraining_completed:

            print("<Agg>: Performing Watermark Pre-training")

            for i in range(self.pretrain_epochs):

                watermark_pretrain_loss = train_model(
                    self.model,
                    self.watermark_pretrain_optimizer,
                    self.watermark_data_loader,
                    "<Agg>:",
                    i,
                    log=False,
                )
                watermark_pretrain_validation_score = inference(
                    self.model, self.watermark_data_loader
                )

                print(
                    "<Agg>: Watermark Pretraining: Round: {:<3} Loss: {:<.6f} Acc: {:<.6f}".format(
                        i,
                        watermark_pretrain_loss,
                        watermark_pretrain_validation_score,
                    )
                )

            self.watermark_pretraining_completed = True

        self.next(
            self.aggregated_model_validation,
            foreach="subset_collaborators",
            exclude=["watermark_pretrain_optimizer", "watermark_retrain_optimizer"],
        )

    @collaborator
    def aggregated_model_validation(self):
        """
        Perform Aggregated Model validation on Collaborators.
        """
        self.agg_validation_score = inference(self.model, self.test_loader)
        print(
            f"<Collab: {self.input}> Aggregated Model validation score = {self.agg_validation_score}"
        )

        self.next(self.train)

    @collaborator
    def train(self):
        """
        Train model on Local collab dataset.

        """
        print("<Collab>: Performing Model Training on Local dataset ... ")

        self.optimizer = optim.SGD(
            self.model.parameters(), lr=learning_rate, momentum=momentum
        )

        self.loss = train_model(
            self.model,
            self.optimizer,
            self.train_loader,
            "<Collab: {:<20}".format(self.input + ">"),
            self.round_number if self.round_number is not None else 0,
            log=True,
        )

        self.next(self.local_model_validation)

    @collaborator
    def local_model_validation(self):
        """
        Validate locally trained model.

        """
        self.local_validation_score = inference(self.model, self.test_loader)
        print(
            f"<Collab: {self.input}> Local model validation score = {self.local_validation_score}"
        )
        self.next(self.join)

    @aggregator
    def join(self, inputs):
        """
        Model aggregation step.
        """

        self.average_loss = sum(input.loss for input in inputs) / len(inputs)
        self.aggregated_model_accuracy = sum(
            input.agg_validation_score for input in inputs
        ) / len(inputs)
        self.local_model_accuracy = sum(
            input.local_validation_score for input in inputs
        ) / len(inputs)

        print(f"<Agg>: Joining models from collaborators...")

        print(
            f"   Aggregated model validation score = {self.aggregated_model_accuracy}"
        )
        print(f"   Average training loss = {self.average_loss}")
        print(f"   Average local model validation values = {self.local_model_accuracy}")

        self.model = FedAvg(self.model, [input.model for input in inputs])

        self.next(self.watermark_retrain)

    @aggregator
    def watermark_retrain(self):
        """
        Retrain the aggregated model.

        """
        print("<Agg>: Performing Watermark Retraining ... ")
        self.watermark_retrain_optimizer = optim.SGD(
            self.model.parameters(), lr=watermark_retrain_learning_rate
        )

        retrain_round = 0

        # Perform re-training until (accuracy >= acc_threshold) or (retrain_round > number of retrain_epochs)
        self.watermark_retrain_validation_score = inference(
            self.model, self.watermark_data_loader
        )
        while (
            self.watermark_retrain_validation_score < self.watermark_acc_threshold
        ) and (retrain_round < self.retrain_epochs):
            self.watermark_retrain_train_loss = train_model(
                self.model,
                self.watermark_retrain_optimizer,
                self.watermark_data_loader,
                "<Agg>",
                retrain_round,
                log=False,
            )
            self.watermark_retrain_validation_score = inference(
                self.model, self.watermark_data_loader
            )

            print(
                "<Agg>: Watermark Retraining: Train Epoch: {:<3} Retrain Round: {:<3} Loss: {:<.6f}, Acc: {:<.6f}".format(
                    self.round_number,
                    retrain_round,
                    self.watermark_retrain_train_loss,
                    self.watermark_retrain_validation_score,
                )
            )

            retrain_round += 1

        self.next(self.end)

    @aggregator
    def end(self):
        """
        This is the last step in the Flow.

        """
        print(f"This is the end of the flow")

# %% [markdown]
# We now initialize certain attributes of the Flow, simulation parameters (seed, batch-sizes, optimizer parameters) and create the `LocalRuntime`
#
# > NOTE: Aggregator based workflow requires a `FederatedRuntime`. In this methodology `FederatedRuntime` is created automatically and it's usage is transparent to the user

# %%
#| export

# Set random seed
random_seed = 42
torch.manual_seed(random_seed)
np.random.seed(random_seed)
torch.backends.cudnn.enabled = False

# Batch sizes
batch_size_train = 64
batch_size_test = 64
batch_size_watermark = 50

# MNIST parameters
learning_rate = 5e-2
momentum = 5e-1
log_interval = 20

# Watermarking parameters
watermark_pretrain_learning_rate = 1e-1
watermark_pretrain_momentum = 5e-1
watermark_pretrain_weight_decay = 5e-05
watermark_retrain_learning_rate = 5e-3

# %%
#| export

def callable_to_initialize_aggregator_private_attributes(watermark_data, batch_size):
    return {
        "watermark_data_loader": torch.utils.data.DataLoader(
            watermark_data, batch_size=batch_size, shuffle=True
        ),
        "pretrain_epochs": 25,
        "retrain_epochs": 25,
        "watermark_acc_threshold": 0.98,
    }

# Setup Aggregator private attributes via callable function
aggregator = Aggregator(
        name="agg",
        private_attributes_callable=callable_to_initialize_aggregator_private_attributes,
        watermark_data=watermark_data,
        batch_size=batch_size_watermark,
    )

collaborator_names = [
    "Portland",
    "Seattle",
    "Chandler",
    "Bangalore",
    "New Delhi",
]
n_collaborators = len(collaborator_names)

def callable_to_initialize_collaborator_private_attributes(index, n_collaborators, batch_size, train_dataset, test_dataset):
    train = deepcopy(train_dataset)
    test = deepcopy(test_dataset)
    train.data = train_dataset.data[index::n_collaborators]
    train.targets = train_dataset.targets[index::n_collaborators]
    test.data = test_dataset.data[index::n_collaborators]
    test.targets = test_dataset.targets[index::n_collaborators]

    return {
        "train_loader": torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True),
        "test_loader": torch.utils.data.DataLoader(test, batch_size=batch_size, shuffle=True),
    }

# Setup Collaborators private attributes via callable function
collaborators = []
for idx, collaborator_name in enumerate(collaborator_names):
    collaborators.append(
        Collaborator(
            name=collaborator_name, num_cpus=0, num_gpus=0,
            private_attributes_callable=callable_to_initialize_collaborator_private_attributes,
            index=idx, n_collaborators=n_collaborators,
            train_dataset=mnist_train, test_dataset=mnist_test, batch_size=64
        )
    )

local_runtime = LocalRuntime(aggregator=aggregator, collaborators=collaborators, backend="ray")
print(f"Local runtime collaborators = {local_runtime.collaborators}")

# %% [markdown]
# Now that we have our flow and runtime defined, let's run the experiment!

# %%
#| export

model = Net()
optimizer = optim.SGD(
    model.parameters(), lr=learning_rate, momentum=momentum
)
watermark_pretrain_optimizer = optim.SGD(
    model.parameters(),
    lr=watermark_pretrain_learning_rate,
    momentum=watermark_pretrain_momentum,
    weight_decay=watermark_pretrain_weight_decay,
)
watermark_retrain_optimizer = optim.SGD(
    model.parameters(), lr=watermark_retrain_learning_rate
)
best_model = None
round_number = 0
top_model_accuracy = 0

flflow = FederatedFlow_MNIST_Watermarking(
    model,
    optimizer,
    watermark_pretrain_optimizer,
    watermark_retrain_optimizer,
    round_number,
    checkpoint=True,
)
flflow.runtime = local_runtime

# %% [markdown]
# ## Workspace creation

# %% [markdown]
# The following cells convert the Jupyter notebook into a Python script and create a Template Workspace that can be utilized by Aggregator based Workflow
# > NOTE: Only Notebook cells that were marked with `#| export` directive shall be included in this Python script
#
# We first import `WorkspaceExport` module and execute `WorkspaceExport.export()` that converts the notebook and generates the template workspace. User is required to specify:
# 1. `notebook_path`: path of the Jupyter notebook that is required to be converted
# 2. `output_workspace`: path where the converted workspace is stored

# %%
import os
from openfl.experimental.workspace_export import WorkspaceExport

WorkspaceExport.export(
    notebook_path='./Workflow_Interface_1001_Workspace_Creation_from_JupyterNotebook.ipynb',
    output_workspace=f"/home/{os.environ['USER']}/generated-workspace"
)

# %% [markdown]
# ## Workspace Usage
#
# The workspace crated above can be used by the Aggregator based workflow by using the `fx` commands in the following manner

# %% [markdown]
# **Workspace Activation and Creation**
# 1. Activate the experimental aggregator-based workflow:
#
#     `fx experimental activate`
# 2. Create a workspace using the custom template:
#
#     `fx workspace create --prefix workspace_path --custom_template /home/$USER/generated-workspace`
# 3. Change to the workspace directory:
#
#     `cd workspace_path`
#
# **Workspace Initialization and Certification**
# 1. Initialize the FL plan and auto-populate the fully qualified domain name (FQDN) of the aggregator node:
#
#     `fx plan initialize`
# 2. Certify the workspace:
#
#     `fx workspace certify`
#
# **Aggregator Setup and Workspace Export**
# 1. Run the aggregator certificate creation command:
#
#     `fx aggregator generate-cert-request`
#
#     `fx aggregator certify`
# 2. Export the workspace for collaboration:
#
#     `fx workspace export`
#
# **Collaborator Node Setup**
#
# ***On the Collaborator Node:***
#
# 1. Copy the workspace archive from the aggregator node to the collaborator nodes. Import the workspace archive:
#
#     `fx workspace import --archive WORKSPACE.zip`
# 2. Generate a collaborator certificate request:
#
#     `fx collaborator generate-cert-request -n {COL_LABEL}`
#
# ***On the Aggregator Node (Certificate Authority):***
#
# 3. Sign the Collaborator Certificate Signing Request (CSR) Package from collaborator nodes:
#
#     `fx collaborator certify --request-pkg /PATH/TO/col_{COL_LABEL}_to_agg_cert_request.zip`
#
# ***On the Collaborator Node:***
#
# 4. Import the signed certificate and certificate chain into the workspace:
#
#     `fx collaborator certify --import /PATH/TO/agg_to_col_{COL_LABEL}_signed_cert.zip`
#
# **Final Workspace Activation**
# ***On the Aggregator Node:***
#
# 1. Start the Aggregator:
#
#     `fx aggregator start`
#
#     The Aggregator is now running and waiting for Collaborators to connect.
#
# ***On the Collaborator Nodes:***
#
# 2. Run the Collaborator:
#
#     `fx collaborator start -n {COL_LABEL}`
